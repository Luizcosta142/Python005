# %% [markdown]
# <a href="https://colab.research.google.com/github/Luizcosta142/postech_fase_1/blob/aula_3/Produ%C3%A7%C3%A3o_Hospitalar_32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisando dados de produção hospitalar

# %% [markdown]
# ### 1.2

# %%
import pandas as pd

# %%
# dados é um DataFrame
dados = pd.read_csv("/content/A150850189_28_143_208.csv", encoding="ISO-8859-1",
            skiprows=3, sep=";", skipfooter=12, thousands=".", decimal=",")
# Out:
# <ipython-input-2-03c29c83551f>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("/content/A150850189_28_143_208.csv", encoding="ISO-8859-1",

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2021/Jan     2021/Fev     2021/Mar  \
# 0        -        -        -  ...  10045624.39  10677245.18  18147121.02
# 1        -        -        -  ...   4175526.06   5282655.42   5699597.78
# 2        -        -        -  ...  27406458.57  22341042.63  27923786.94
# 3        -        -        -  ...   3557821.99   4172285.82   5427226.70
# 4        -        -        -  ...  39042349.46  37113440.70  49625416.13
#
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...      2021/Jan      2021/Fev  \
# 22        -        -        -        -  ...  1.159919e+08  1.267303e+08
# 23        -        -        -        -  ...  2.472700e+07  2.560076e+07
# 24        -        -        -        -  ...  1.888971e+07  2.154459e+07
# 25        -        -        -        -  ...  4.263870e+07  4.571547e+07
# 26        -        -        -        -  ...  2.448472e+07  2.415606e+07
#
#         2021/Mar      2021/Abr      2021/Mai      2021/Jun      2021/Jul  \
# ...

# %%
dados.mean()
# Out:
# <ipython-input-5-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2021/Mai    8.727186e+07
# 2021/Jun    7.759041e+07
# 2021/Jul    6.084629e+07
# 2021/Ago    4.388572e+07
# Total       6.852321e+09
# Length: 170, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# <ipython-input-8-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %% [markdown]
# ### 1.3

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42502172.22
# 19   180097396.03
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21070201.36
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26645398.35703704

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

axis = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")

plt.show()

# %% [markdown]
# Desafio 1: executar o gráfico anterior com o mês mais recente

# %% [markdown]
# Desafio 2: deixar as legendas ânguladas (0, 45 etc) para facilitar a leitura

# %% [markdown]
# ### 2.1

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# 1        -        -        -  ...  4175526.06  5282655.42  5699597.78
# 2        -        -        -  ... 27406458.57 22341042.63 27923786.94
# 3        -        -        -  ...  3557821.99  4172285.82  5427226.70
# 4        -        -        -  ... 39042349.46 37113440.70 49625416.13
#
#      2021/Abr    2021/Mai    2021/Jun    2021/Jul    2021/Ago    2021/Set  \
# ...

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai', '2021/Jun',
#        '2021/Jul', '2021/Ago', '2021/Set', 'Total'],
#       dtype='object', length=293)

# %%
dados.mean()
# Out:
# <ipython-input-16-99af3ba13e28>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dados.mean()
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis[:5]
# Out:
# <ipython-input-17-6d9cbc9c14ab>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   colunas_usaveis = dados.mean().index.tolist()
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  9469279.43
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3820865.83
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 21911210.94
# 3   808448.39   771687.83   876091.18   896952.53  ...  3193708.89
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 37925512.28
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# ...

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
dados_usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2021/Mai               17659855.79   4326882.24   23973537.71   3681417.80
# 2021/Jun               14435903.47   3458187.11   22175398.40   3475205.55
# 2021/Jul               11834435.10   2302711.01   21614943.55   3320807.96
# 2021/Ago                7371334.84   1196754.85   13806958.66   2907871.07
# Total                1088059702.25 475290315.34 2061943006.93 352546288.71
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2021/Mai               50907226.77   5672086.52   10161783.68   55324683.42
# 2021/Jun               43876590.47   5469150.38    6349488.16   51958573.27
# 2021/Jul               33718084.12   4136950.62    4610170.61   37775425.78
# 2021/Ago               20837865.89   1875241.91    2304080.49   25779674.83
# Total                4968811817.17 337181964.14 1110344733.46 4161325769.23
#
# ...

# %%
dados_usaveis = dados_usaveis.drop("Total", axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37   10470.07     35752.72     4785.91
# 2007/Set                 16397.03   14001.71     45570.64    11858.63
# 2007/Out                133645.19   86200.85    416012.30    43852.67
# 2007/Nov                346912.84  301323.68   2020381.79   369328.51
# 2007/Dez                711758.31  769612.36   5949408.99   470676.43
# ...                           ...        ...          ...         ...
# 2021/Abr              17753851.45 5002272.59  24515920.09  4192540.54
# 2021/Mai              17659855.79 4326882.24  23973537.71  3681417.80
# 2021/Jun              14435903.47 3458187.11  22175398.40  3475205.55
# 2021/Jul              11834435.10 2302711.01  21614943.55  3320807.96
# 2021/Ago               7371334.84 1196754.85  13806958.66  2907871.07
#
# Unidade da Federação     15 Pará   16 Amapá  17 Tocantins  21 Maranhão  \
# ...

# %% [markdown]
# Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %% [markdown]
# Desafio: retocar a nossa visualização.

# %% [markdown]
# Desafio: colocar títulos nos dois eixos.

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:5]
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 21 Maranhão          385330.18 1018352.93 2277717.78 4334468.23  8832514.85
# 25 Paraíba            97352.78  368130.43 1002088.64 2149873.40  5448177.36
# 32 Espírito Santo     57408.11  284224.80 1152115.25 2296383.23  5724199.54
# 12 Acre               10470.07   14001.71   86200.85  301323.68   769612.36
# 52 Goiás             179395.82  418053.58 1198730.25 2712117.54  9293914.78
# 14 Roraima             4785.91   11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29  433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 21 Maranhão          21551600.33 13452263.93 14750895.33 15148647.11
# 25 Paraíba           16599004.84 10871589.62 12348758.14 12680965.13
# 32 Espírito Santo    16212109.41 10032886.43 12262049.08 12453466.98
# ...

# %%
dados_usaveis.sample(7)
# Out:
#                          2007/Ago   2007/Set   2007/Out    2007/Nov  \
# Unidade da Federação
# 50 Mato Grosso do Sul   199556.12  573675.41 1069816.66  1995899.52
# 24 Rio Grande do Norte  134605.36  272088.08  684678.30  1695824.89
# 43 Rio Grande do Sul   1049252.33 3182913.14 8571312.11 16592432.80
# 11 Rondônia               4209.37   16397.03  133645.19   346912.84
# 33 Rio de Janeiro       469469.34  921646.57 2994664.57  7250528.08
# 51 Mato Grosso           63562.50  232444.62  927219.59  1740439.60
# 52 Goiás                179395.82  418053.58 1198730.25  2712117.54
#
#                           2007/Dez     2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 50 Mato Grosso do Sul   4277979.14   8301006.10  8279288.79  9793888.78
# 24 Rio Grande do Norte  4730811.68  11763899.23  9110108.87 10126626.54
# 43 Rio Grande do Sul   30134255.70  51064610.03 45897704.82 52928695.92
# 11 Rondônia              711758.31   1829559.71  1940792.63  1955721.68
# ...

# %%
dados_usaveis.sample(7).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
# pseudo aleatorio... pseudo randomness
# 53874 = seed
# regra semente / 10, semente * 3 / 2
# 80811
# regra 8081, 121216

# %%
import numpy as np

np.random.seed(524387)
dados_usaveis.sample(n=7)
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 17 Tocantins           4113.76   76633.06   343702.61  1068685.94  3022200.87
# 26 Pernambuco        400640.85 1088340.42  2973553.48  6699828.82 16919031.39
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 22 Piauí             220788.25  353468.67  1078182.68  2406035.32  4929772.93
# 25 Paraíba            97352.78  368130.43  1002088.64  2149873.40  5448177.36
# 29 Bahia             135146.36  448349.75  1382038.11  3348779.62 11948984.56
# 42 Santa Catarina    693955.05 1092964.12  3562300.82  7578502.38 14772555.10
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins           5136474.61  5051932.07  5200151.87  5343714.73
# 26 Pernambuco         51279301.86 26222079.10 30716361.81 30589332.79
# 31 Minas Gerais      206493861.30 70301089.50 79119005.51 79046322.41
# ...

# %%
dados_dos_7_estados = dados_usaveis.sample(n=7)
dados_dos_7_estados.T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis = 1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %% [markdown]
# Desafio: ordenar nosso DataFrame para que na primeira linha tenha a linha com maior gasto, e na última com menor gasto (ordenação)

# %% [markdown]
# Desafio: adicionar uma coluna com a região de cada estado.

# %% [markdown]
# Desafio: adicione seu estado nessa lista de 7 estados (`dados_dos_7_estados`).

# %% [markdown]
# ### 3.2

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
ordenados_por_total = dados_usaveis.sort_values(by="Total", ascending=False)
ordenados_por_total = ordenados_por_total.drop("Total", axis=1)
# ordenados_por_total.drop("Total", axis=1, inplace=True)
ordenados_por_total
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo           1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais         971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná               554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul   1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro       469469.34  921646.57  2994664.57  7250528.08
# 29 Bahia                135146.36  448349.75  1382038.11  3348779.62
# 26 Pernambuco           400640.85 1088340.42  2973553.48  6699828.82
# 42 Santa Catarina       693955.05 1092964.12  3562300.82  7578502.38
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 52 Goiás                179395.82  418053.58  1198730.25  2712117.54
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# ...

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# Desafio: adicionar seu estado aos 5 estados existentes, e plotar.

# %%
colunas_interessadas = ordenados_por_total.columns[6:]
ordenados_por_total = ordenados_por_total[colunas_interessadas]
ordenados_por_total.head(5)
# Out:
#                          2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 35 São Paulo         173062308.33 170621304.31 170389849.75 172513744.39
# 31 Minas Gerais       70301089.50  79119005.51  79046322.41  79268070.12
# 41 Paraná             48855046.46  55611791.07  56115135.82  55574831.93
# 43 Rio Grande do Sul  45897704.82  52928695.92  51972416.77  51679350.79
# 33 Rio de Janeiro     44128159.73  42907909.35  45315594.87  43951349.46
#
#                          2008/Jun     2008/Jul     2008/Ago     2008/Set  \
# Unidade da Federação
# 35 São Paulo         175557604.00 179608674.95 180097396.03 180211608.05
# 31 Minas Gerais       79628284.54  82216960.75  80374117.08  82416883.07
# 41 Paraná             56094754.74  59802402.07  56699001.13  58091985.79
# 43 Rio Grande do Sul  53759674.01  56391647.77  56233758.74  57910170.98
# 33 Rio de Janeiro     44118169.60  44360299.24  42502172.22  43066461.47
#
# ...

# %% [markdown]
# Desafio: adicionar seu estado. ✅

# %% [markdown]
# Desafio: deixar o gráfico mais refinado. ✅

# %% [markdown]
# Desafio: pesquisar o `sort_index`. ✅

# %% [markdown]
# Desafio: googlar os casos de dengue do Brasil e verificar se existe algum padrão com os gastos encontrados aqui.

# %% [markdown]
# Desafio: plotar somente os estados de uma região do Brasil. ✅

# %%
ordenados_por_total_novo = ordenados_por_total.head(5).append(ordenados_por_total.loc['50 Mato Grosso do Sul'])
ordenados_por_total_novo
# Out:
# <ipython-input-78-b1389d21ddb9>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ordenados_por_total_novo = ordenados_por_total.head(5).append(ordenados_por_total.loc['50 Mato Grosso do Sul'])
#                           2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 35 São Paulo          173062308.33 170621304.31 170389849.75 172513744.39
# 31 Minas Gerais        70301089.50  79119005.51  79046322.41  79268070.12
# 41 Paraná              48855046.46  55611791.07  56115135.82  55574831.93
# 43 Rio Grande do Sul   45897704.82  52928695.92  51972416.77  51679350.79
# 33 Rio de Janeiro      44128159.73  42907909.35  45315594.87  43951349.46
# 50 Mato Grosso do Sul   8279288.79   9793888.78   8997542.75   9842108.59
#
#                           2008/Jun     2008/Jul     2008/Ago     2008/Set  \
# Unidade da Federação
# ...

# %%
ordenados_por_total_novo.T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(15,6))
ax.plot(ordenados_por_total_novo.T)
ax.set_title('Produção Hospitalar por UF')
ax.set_xlabel('Mês/Ano')
ax.set_ylabel('Valor gasto')
ax.xaxis.set_major_locator(plt.MultipleLocator(4))
plt.xticks(rotation=75)
ax.legend(dados_usaveis.T.columns, loc = 'best', title = 'UF')

plt.show()

# %%
ordenados_por_total.sort_index()
# Out:
#                            2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 11 Rondônia              1940792.63   1955721.68   2143353.81   2280382.58
# 12 Acre                  1743978.66   2057439.02   2057829.69   2226577.93
# 13 Amazonas              7934652.10   8641517.13   8531576.49   9079902.15
# 14 Roraima                771687.83    876091.18    896952.53   1027288.73
# 15 Pará                 20126081.01  22149375.82  23436682.75  23861080.80
# 16 Amapá                 1275063.72   1177745.93   1396371.51   1411520.77
# 17 Tocantins             5051932.07   5200151.87   5343714.73   5344487.99
# 21 Maranhão             13452263.93  14750895.33  15148647.11  14543679.92
# 22 Piauí                 9711680.20  10428191.09  10227943.00  10562148.66
# 23 Ceará                27643304.86  30085370.22  31376221.00  31189904.62
# 24 Rio Grande do Norte   9110108.87  10126626.54  10964234.85  11032871.23
# ...

# %%
mapeamento_regiao = {
    '35 São Paulo': 'Sudeste',
    '31 Minas Gerais': 'Sudeste',
    '41 Paraná': 'Sul',
    '43 Rio Grande do Sul': 'Sul',
    '33 Rio de Janeiro': 'Sudeste',
    '29 Bahia': 'Nordeste',
    '26 Pernambuco': 'Nordeste',
    '42 Santa Catarina': 'Sul',
    '23 Ceará': 'Nordeste',
    '52 Goiás': 'Centro-Oeste',
    '15 Pará': 'Norte',
    '21 Maranhão': 'Nordeste',
    '32 Espírito Santo': 'Sudeste',
    '24 Rio Grande do Norte': 'Nordeste',
    '25 Paraíba': 'Nordeste',
    '53 Distrito Federal': 'Centro-Oeste',
    '50 Mato Grosso do Sul': 'Centro-Oeste',
    '22 Piauí': 'Nordeste',
    '27 Alagoas': 'Nordeste',
    '51 Mato Grosso': 'Centro-Oeste',
    '13 Amazonas': 'Norte',
    '28 Sergipe': 'Nordeste',
    '17 Tocantins': 'Norte',
    '11 Rondônia': 'Norte',
    '12 Acre': 'Norte',
    '14 Roraima': 'Norte',
    '16 Amapá': 'Norte'
}

ordenados_por_total['Região'] = ordenados_por_total.index.map(mapeamento_regiao)
ordenados_index = ordenados_por_total.sort_index()
# Out:
# <ipython-input-120-5e5ddff527d9>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ordenados_por_total['Região'] = ordenados_por_total.index.map(mapeamento_regiao)

# %%
ordenados_index = ordenados_index.set_index("Região")
ordenados_index.head()
# Out:
#           2008/Fev    2008/Mar    2008/Abr    2008/Mai    2008/Jun  \
# Região
# Norte   1940792.63  1955721.68  2143353.81  2280382.58  2624542.97
# Norte   1743978.66  2057439.02  2057829.69  2226577.93  2112576.82
# Norte   7934652.10  8641517.13  8531576.49  9079902.15  8646295.77
# Norte    771687.83   876091.18   896952.53  1027288.73   938293.54
# Norte  20126081.01 22149375.82 23436682.75 23861080.80 23502915.90
#
#           2008/Jul    2008/Ago    2008/Set    2008/Out    2008/Nov  ...  \
# Região                                                              ...
# Norte   2973421.02  2938286.29  2843930.91  2878153.20  2780022.62  ...
# Norte   2029128.01  1886871.84  2084884.80  2230838.45  2122013.12  ...
# Norte   8755806.50  8331763.97  8148089.92  7681661.02  7761445.21  ...
# Norte   1004340.44  1045291.11  1003740.89  1055063.43  1223200.73  ...
# Norte  22544291.26 23259148.28 23667690.01 23352577.75 23537613.41  ...
#
# ...

# %%
ordenados_index_agrupado = ordenados_index.groupby("Região").sum()
ordenados_index_agrupado
# Out:
#                  2008/Fev     2008/Mar     2008/Abr     2008/Mai     2008/Jun  \
# Região
# Centro-Oeste  44574514.79  51830387.75  51359623.44  50283669.63  52070846.51
# Nordeste     143170221.70 164014141.11 169546980.47 169322012.39 161327681.31
# Norte         38844188.02  42058042.63  43806481.51  45231240.95  44643930.10
# Sudeste      297524443.99 304910268.25 307205234.01 307522950.06 311193745.49
# Sul          119162324.20 136023967.49 135894194.03 135608462.24 138847721.51
#
#                  2008/Jul     2008/Ago     2008/Set     2008/Out     2008/Nov  \
# Região
# Centro-Oeste  51295551.26  51209308.69  52964182.89  53081928.67  52104933.78
# Nordeste     182631707.98 166813086.44 168149195.92 170330608.76 165396711.32
# Norte         43735684.31  44224992.50  44499904.46  44847041.79  44277312.77
# Sudeste      318391519.08 315357753.52 318181905.20 338012426.22 329982292.57
# Sul          146243505.53 141820614.49 146727875.55 152232461.75 147231586.48
#
# ...

# %%
fig, ax = plt.subplots(figsize=(15,6))
ax.plot(ordenados_index_agrupado.T)
ax.set_title('Produção Hospitalar por UF')
ax.set_xlabel('Mês/Ano')
ax.set_ylabel('Valor gasto')
ax.xaxis.set_major_locator(plt.MultipleLocator(4))
plt.xticks(rotation=75)
ax.legend(ordenados_index_agrupado.T.columns, loc = 'best', title = 'UF')

plt.show()

# %% [markdown]
# #OBS
#
# Em um segundo momento vou revistar a aula para cumprir o desafio de comparação de bases com os casos de dengue para analisar algum possível padrão.
